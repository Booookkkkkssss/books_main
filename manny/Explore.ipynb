# %%
import os
import pandas as pd

# %%
def read_csv(file_path):
    '''
    Reads a file from the specified path and returns a Pandas DataFrame.

    Parameters:
    -----------
    file_path (str): The path to the input file.

    Returns:
    -----------
    df (Pandas DataFrame): The contents of the input file as a DataFrame, or None if the file does not exist.
    '''

    # check if file exists
    if not os.path.exists(file_path):
        print(f"Error: {file_path} does not exist.")
        return None

    # read file and convert to DataFrame
    try:
        df = pd.read_csv(file_path,index_col=0)
        return df

    except Exception as e:
        print(f"Error: Failed to read {file_path} as a DataFrame.")
        print(e)
        return None

# %%
def drop_nulls(df):
    '''
    Drops rows with null values that are less than 1% of the total and columns with null values
    that are greater than 30% of the total.

    Parameters:
    -----------
    df (Pandas DataFrame): The input DataFrame to be processed.

    Returns:
    -----------
    df (Pandas DataFrame): The processed DataFrame.
    '''
    
    # Calculate the percentage of null values in each column
    percent_null = df.isnull().sum() / len(df)

    # Drop columns with null values exceeding 30%
    columns_to_drop = percent_null[percent_null > 0.3].index
    df = df.drop(columns=columns_to_drop)

    # Drop rows with null values less than 1%
    rows_to_drop = df.isnull().sum(axis=1) / len(df.columns) < 0.01
    df = df.loc[rows_to_drop, :]

    return df

# %%
df = read_csv("almost_there.csv")

# %%
df = drop_nulls(df)

# %%
df = df.reset_index(drop=True)

# %%
df.head(15)
# Out:
#                                         title  \
# 0        Harry Potter and the Deathly Hallows
# 1                            The Hunger Games
# 2                             The Kite Runner
# 3                              The Book Thief
# 4      Harry Potter and the Half-Blood Prince
# 5   Harry Potter and the Order of the Phoenix
# 6                                    The Help
# 7                    A Thousand Splendid Suns
# 8                                  Life of Pi
# 9                               Catching Fire
# 10            The Girl with the Dragon Tattoo
# 11                   The Time Traveler's Wife
# 12                     The Fault in Our Stars
# 13                          The Da Vinci Code
# 14                                   The Road
#
#                                               summary year_published  \
# 0   Harry has been burdened with a dark, dangerous...           2007
# 1   Could you survive on your own in the wild, wit...           2008
# 2   1970s Afghanistan: Twelve-year-old Amir is des...           2003
# 3   Librarian's note: An alternate cover edition c...           2006
# 4   It is the middle of the summer, but there is a...           2005
# 5   Harry Potter is about to start his fifth year ...           2003
# 6   Three ordinary women are about to take one ext...           2009
# 7   Mariam is only fifteen when she is sent to Kab...           2007
# 8   Life of Pi is a fantasy adventure novel by Yan...           2001
# 9   Sparks are igniting.Flames are spreading.And t...           2009
# 10  Harriet Vanger, a scion of one of Sweden’s wea...           2005
# 11  This is the extraordinary love story of Clare ...           2003
# 12  Despite the tumor-shrinking medical miracle th...           2012
# 13  ISBN 9780307277671 moved to this edition.While...           2003
# 14  A searing, postapocalyptic novel destined to b...           2006
#
#                 author  review_count  number_of_ratings length  \
# 0         J.K. Rowling         78723            3439426    759
# 1      Suzanne Collins        192533            7882293    374
# 2      Khaled Hosseini         90080            2931026    371
# 3         Markus Zusak        134634            2341042    552
# 4         J.K. Rowling         51340            3021655    652
# 5         J.K. Rowling         56241            3119007    912
# 6     Kathryn Stockett         88236            2582493    464
# 7      Khaled Hosseini         69244            1414796    372
# 8          Yann Martel         51216            1542892    460
# 9      Suzanne Collins        108020            3192911    391
# 10       Stieg Larsson         74367            3014678    480
# 11  Audrey Niffenegger         51498            1729995    537
# 12          John Green        171936            4716748    313
# 13           Dan Brown         52302            2235823    489
# 14     Cormac McCarthy         53190             834080    241
#
#                  genre  rating
# 0              Fantasy    4.62
# 1          Young Adult    4.33
# 2              Fiction    4.33
# 3   Historical Fiction    4.39
# 4              Fantasy    4.58
# 5              Fantasy    4.50
# 6              Fiction    4.47
# 7              Fiction    4.42
# 8              Fiction    3.93
# 9          Young Adult    4.31
# 10             Fiction    4.16
# 11             Fiction    3.99
# 12         Young Adult    4.15
# 13             Fiction    3.90
# 14             Fiction    3.98
