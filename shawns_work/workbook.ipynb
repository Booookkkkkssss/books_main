# %%
import requests
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup 
import time

# %%
url = f'https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century?page={num}'

response = requests.get(url)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="desktop withSiteHeaderTopFullImage">
# <head>
# <title>Best Books of the 21st Century (9626 books)</title>
# <meta content="9,586 books based on 21954 votes: Harry Potter and the Deathly Hallows by J.K. Rowling, The Hunger Games by Suzanne Collins, The Kite Runner by Khaled Ho..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century" rel="canonical"/>
# <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();
#  </script>
# <script type="text/javascript">
#     var ue_mid = "A1PQBFHBHS6YH1";
#     var ue_sn = "www.goodreads.com";
#     var ue_furl = "fls-na.amazon.com";
#     var ue_sid = "291-8475041-2618409";
#     var ue_id = "M3ARTESEEZMN3AFFJ2CS";
#
# ...

# %%
page1 = soup.find_all('a', class_='bookTitle')

# %%
page1
# Out:
# [<a class="bookTitle" href="/book/show/136251.Harry_Potter_and_the_Deathly_Hallows" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">Harry Potter and the Deathly Hallows (Harry Potter, #7)</span>
#  </a>,
#  <a class="bookTitle" href="/book/show/2767052-the-hunger-games" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">The Hunger Games (The Hunger Games, #1)</span>
#  </a>,
#  <a class="bookTitle" href="/book/show/77203.The_Kite_Runner" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">The Kite Runner</span>
#  </a>,
#  <a class="bookTitle" href="/book/show/19063.The_Book_Thief" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">The Book Thief</span>
#  </a>,
#  <a class="bookTitle" href="/book/show/1.Harry_Potter_and_the_Half_Blood_Prince" itemprop="url">
#  <span aria-level="4" itemprop="name" role="heading">Harry Potter and the Half-Blood Prince (Harry Potter, #6)</span>
#  </a>,
# ...

# %%
test = page1[0]['href']

# %%
test
# Out:
# '/book/show/136251.Harry_Potter_and_the_Deathly_Hallows'

# %%
re.search(r'\d.*', test)
# Out:
# <re.Match object; span=(11, 54), match='136251.Harry_Potter_and_the_Deathly_Hallows'>

# %%
len(page1)
# Out:
# 100

# %%
book_ids = []

for i in range(0, len(page1)):
    
    href = page1[i]['href']
               
    book_ids.append(re.findall(r'\d.*', href))

# %%
book_ids
# Out:
# [['136251.Harry_Potter_and_the_Deathly_Hallows'],
#  ['2767052-the-hunger-games'],
#  ['77203.The_Kite_Runner'],
#  ['19063.The_Book_Thief'],
#  ['1.Harry_Potter_and_the_Half_Blood_Prince'],
#  ['2.Harry_Potter_and_the_Order_of_the_Phoenix'],
#  ['4667024-the-help'],
#  ['128029.A_Thousand_Splendid_Suns'],
#  ['4214.Life_of_Pi'],
#  ['6148028-catching-fire'],
#  ['2429135.The_Girl_with_the_Dragon_Tattoo'],
#  ['18619684-the-time-traveler-s-wife'],
#  ['11870085-the-fault-in-our-stars'],
#  ['968.The_Da_Vinci_Code'],
#  ['6288.The_Road'],
#  ['1618.The_Curious_Incident_of_the_Dog_in_the_Night_Time'],
#  ['43641.Water_for_Elephants'],
#  ['7260188-mockingjay'],
#  ['2187.Middlesex'],
#  ['12232938-the-lovely-bones'],
#  ['28187.The_Lightning_Thief'],
#  ['13335037-divergent'],
#  ['41865.Twilight'],
#  ['6867.Atonement'],
#  ['30165203-american-gods'],
#  ['1232.The_Shadow_of_the_Wind'],
#  ['256683.City_of_Bones'],
#  ['7445.The_Glass_Castle'],
#  ['37435.The_Secret_Life_of_Bees'],
# ...

# %%
books = []

for i in range(0, 50):
    
    url = f'https://www.goodreads.com/list/show/7.Best_Books_of_the_21st_Century?page={i}'

    response = requests.get(url)
    
    soup = BeautifulSoup(response.content, 'html.parser')

    page = soup.find_all('a', class_='bookTitle')
    
    print(response.status_code)
    
    for i in range(0, len(page)):
    
        href = page1[i]['href']
               
        books.append(re.findall(r'\d.*', href))
        
    time.sleep(5)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
len(books)
# Out:
# 5000

# %%
book_list = []

#url = 'https://www.goodreads.com/book/show/' + book_id


for i in range(len(books)):
    
    book = books[i][0]
    
    book_list.append(book)

# %%
book_list
# Out:
# ['136251.Harry_Potter_and_the_Deathly_Hallows',
#  '2767052-the-hunger-games',
#  '77203.The_Kite_Runner',
#  '19063.The_Book_Thief',
#  '1.Harry_Potter_and_the_Half_Blood_Prince',
#  '2.Harry_Potter_and_the_Order_of_the_Phoenix',
#  '4667024-the-help',
#  '128029.A_Thousand_Splendid_Suns',
#  '4214.Life_of_Pi',
#  '6148028-catching-fire',
#  '2429135.The_Girl_with_the_Dragon_Tattoo',
#  '18619684-the-time-traveler-s-wife',
#  '11870085-the-fault-in-our-stars',
#  '968.The_Da_Vinci_Code',
#  '6288.The_Road',
#  '1618.The_Curious_Incident_of_the_Dog_in_the_Night_Time',
#  '43641.Water_for_Elephants',
#  '7260188-mockingjay',
#  '2187.Middlesex',
#  '12232938-the-lovely-bones',
#  '28187.The_Lightning_Thief',
#  '13335037-divergent',
#  '41865.Twilight',
#  '6867.Atonement',
#  '30165203-american-gods',
#  '1232.The_Shadow_of_the_Wind',
#  '256683.City_of_Bones',
#  '7445.The_Glass_Castle',
#  '37435.The_Secret_Life_of_Bees',
#  '4588.Extremely_Loud_Incredibly_Close',
# ...

# %%
books[1][0]
# Out:
# '2767052-the-hunger-games'

# %%
#book.to_csv('book_ids.txt')

# %%
with open("file.txt", "w") as output:
#    output.write(str(book_list))
    for i in book_list:
        output.write(i + '\n')
